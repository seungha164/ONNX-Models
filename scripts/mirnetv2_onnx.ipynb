# %%
import cv2
import yaml
import numpy as np
from matplotlib import pyplot as plt

import torch
from torch.nn import functional as F

import onnx
import onnxruntime
from onnxruntime.quantization import QuantType
from onnxruntime.quantization.quantize import quantize_dynamic

# %% [markdown]
# ## Export an ONNX model
# #### 모델 불러오기 - MIRNetv2

# %%
from basicsr.models.archs.mirnet_v2_arch import MIRNet_v2
try:
    from yaml import CLoader as Loader
except ImportError:
    from yaml import Loader

#* config & pretrained-weight 경로 설정
yaml_file  = './Enhancement/Options/Enhancement_MIRNet_v2_FiveK.yml'  # config 경로
weights  = 'pretrained_models/enhancement_fivek.pth'     # 모델 가중치 경로

#* model 불러오기
x = yaml.load(open(yaml_file, mode='r'), Loader=Loader)
s = x['network_g'].pop('type')
model_restoration = MIRNet_v2(**x['network_g'])
checkpoint = torch.load(weights)
model_restoration.load_state_dict(checkpoint['params'])

model_restoration.cuda()

model_restoration.eval()

print("===>Testing using weights: ",weights)
print('모델 로딩 완')
# Out:
# ===>Testing using weights:  pretrained_models/enhancement_fivek.pth
# 모델 로딩 완

# %% [markdown]
# ##### 모델 작동 여부 확인 및 input 값 체크

# %%
import Enhancement.utils as utils

factor = 4

img = np.float32(utils.load_img('demo/restored/real_denoising/1.png'))/255.
img = cv2.resize(img, (512, 512))
img = torch.from_numpy(img).permute(2,0,1)
input_ = img.unsqueeze(0)
# Padding in case images are not multiples of 4
h,w = input_.shape[2], input_.shape[3]
H,W = ((h+factor)//factor)*factor, ((w+factor)//factor)*factor
padh = H-h if h%factor!=0 else 0
padw = W-w if w%factor!=0 else 0
input_ = F.pad(input_, (0,padw,0,padh), 'reflect').cuda()

restored = model_restoration(input_)

# %% [markdown]
# #### onnx 변환

# %%
# onnx 모델 저장 경로
onnx_model_path = './onnx_models/MIRNetv2_gpu_softmax.onnx'
device    = torch.device('cuda')
dummy_inputs = {
    "input" : torch.as_tensor(np.ones([1, 3, 256, 256]), dtype = torch.float32).to(device)
}
output_names = ["output"]

torch.onnx.export(
        model=model_restoration,                            # 실행될 모델
        args = tuple(dummy_inputs.values()),        # 모델 입력값(tuple or 여러 입력값)
        f = onnx_model_path,                     # 모델 저장 경로
        export_params=True,                 # 모델 파일 안에 학습된 모델 가중치 저장 여부
        opset_version=13,                   # 모델 변환할 때 사용할 onnx 버전
        do_constant_folding = True,         # 최적화시 상수폴딩 사용할지 여부
        input_names=list(dummy_inputs.keys()),
        output_names=output_names,
        dynamic_axes={
            'input'     : {0 : 'batch_size'},    # 가변적인 길이를 가진 차원
            'output'    : {0 : 'batch_size'}
        }
    )
# Out:
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %%
onnx_model = onnx.load(onnx_model_path)
onnx.checker.check_model(onnx_model)
print('The ONNX model  is valid')
print(onnx.helper.printable_graph(onnx_model.graph))
# Out:
# The ONNX model  is valid
# graph torch_jit (
#   %input[FLOAT, batch_sizex3x256x256]
# ) initializers (
#   %conv_in.weight[FLOAT, 80x3x3x3]
#   %body.0.body.0.dau_top.body.0.weight[FLOAT, 80x80x3x3]
#   %body.0.body.0.dau_top.body.2.weight[FLOAT, 80x80x3x3]
#   %body.0.body.0.dau_top.gcnet.conv_mask.weight[FLOAT, 1x80x1x1]
#   %body.0.body.0.dau_top.gcnet.channel_add_conv.0.weight[FLOAT, 80x80x1x1]
#   %body.0.body.0.dau_top.gcnet.channel_add_conv.2.weight[FLOAT, 80x80x1x1]
#   %body.0.body.0.dau_mid.body.0.weight[FLOAT, 120x120x3x3]
#   %body.0.body.0.dau_mid.body.2.weight[FLOAT, 120x120x3x3]
#   %body.0.body.0.dau_mid.gcnet.conv_mask.weight[FLOAT, 1x120x1x1]
#   %body.0.body.0.dau_mid.gcnet.channel_add_conv.0.weight[FLOAT, 120x120x1x1]
#   %body.0.body.0.dau_mid.gcnet.channel_add_conv.2.weight[FLOAT, 120x120x1x1]
#   %body.0.body.0.dau_bot.body.0.weight[FLOAT, 180x180x3x3]
#   %body.0.body.0.dau_bot.body.2.weight[FLOAT, 180x180x3x3]
#   %body.0.body.0.dau_bot.gcnet.conv_mask.weight[FLOAT, 1x180x1x1]
#   %body.0.body.0.dau_bot.gcnet.channel_add_conv.0.weight[FLOAT, 180x180x1x1]
#   %body.0.body.0.dau_bot.gcnet.channel_add_conv.2.weight[FLOAT, 180x180x1x1]
#   %body.0.body.0.down2.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.0.body.0.down4.0.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.0.body.0.down4.1.body.0.bot.1.weight[FLOAT, 180x120x1x1]
#   %body.0.body.0.up21_1.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.0.body.0.up21_2.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.0.body.0.up32_1.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.0.body.0.up32_2.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.0.body.0.conv_out.weight[FLOAT, 80x80x1x1]
#   %body.0.body.0.skff_top.conv_du.0.weight[FLOAT, 10x80x1x1]
#   %body.0.body.0.skff_top.fcs.0.weight[FLOAT, 80x10x1x1]
#   %body.0.body.0.skff_top.fcs.1.weight[FLOAT, 80x10x1x1]
#   %body.0.body.0.skff_mid.conv_du.0.weight[FLOAT, 15x120x1x1]
#   %body.0.body.0.skff_mid.fcs.0.weight[FLOAT, 120x15x1x1]
#   %body.0.body.0.skff_mid.fcs.1.weight[FLOAT, 120x15x1x1]
#   %body.0.body.1.dau_top.body.0.weight[FLOAT, 80x80x3x3]
#   %body.0.body.1.dau_top.body.2.weight[FLOAT, 80x80x3x3]
#   %body.0.body.1.dau_top.gcnet.conv_mask.weight[FLOAT, 1x80x1x1]
#   %body.0.body.1.dau_top.gcnet.channel_add_conv.0.weight[FLOAT, 80x80x1x1]
#   %body.0.body.1.dau_top.gcnet.channel_add_conv.2.weight[FLOAT, 80x80x1x1]
#   %body.0.body.1.dau_mid.body.0.weight[FLOAT, 120x120x3x3]
#   %body.0.body.1.dau_mid.body.2.weight[FLOAT, 120x120x3x3]
#   %body.0.body.1.dau_mid.gcnet.conv_mask.weight[FLOAT, 1x120x1x1]
#   %body.0.body.1.dau_mid.gcnet.channel_add_conv.0.weight[FLOAT, 120x120x1x1]
#   %body.0.body.1.dau_mid.gcnet.channel_add_conv.2.weight[FLOAT, 120x120x1x1]
#   %body.0.body.1.dau_bot.body.0.weight[FLOAT, 180x180x3x3]
#   %body.0.body.1.dau_bot.body.2.weight[FLOAT, 180x180x3x3]
#   %body.0.body.1.dau_bot.gcnet.conv_mask.weight[FLOAT, 1x180x1x1]
#   %body.0.body.1.dau_bot.gcnet.channel_add_conv.0.weight[FLOAT, 180x180x1x1]
#   %body.0.body.1.dau_bot.gcnet.channel_add_conv.2.weight[FLOAT, 180x180x1x1]
#   %body.0.body.1.down2.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.0.body.1.down4.0.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.0.body.1.down4.1.body.0.bot.1.weight[FLOAT, 180x120x1x1]
#   %body.0.body.1.up21_1.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.0.body.1.up21_2.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.0.body.1.up32_1.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.0.body.1.up32_2.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.0.body.1.conv_out.weight[FLOAT, 80x80x1x1]
#   %body.0.body.1.skff_top.conv_du.0.weight[FLOAT, 10x80x1x1]
#   %body.0.body.1.skff_top.fcs.0.weight[FLOAT, 80x10x1x1]
#   %body.0.body.1.skff_top.fcs.1.weight[FLOAT, 80x10x1x1]
#   %body.0.body.1.skff_mid.conv_du.0.weight[FLOAT, 15x120x1x1]
#   %body.0.body.1.skff_mid.fcs.0.weight[FLOAT, 120x15x1x1]
#   %body.0.body.1.skff_mid.fcs.1.weight[FLOAT, 120x15x1x1]
#   %body.0.body.2.weight[FLOAT, 80x80x3x3]
#   %body.1.body.0.dau_top.body.0.weight[FLOAT, 80x40x3x3]
#   %body.1.body.0.dau_top.body.2.weight[FLOAT, 80x40x3x3]
#   %body.1.body.0.dau_top.gcnet.conv_mask.weight[FLOAT, 1x80x1x1]
#   %body.1.body.0.dau_top.gcnet.channel_add_conv.0.weight[FLOAT, 80x80x1x1]
#   %body.1.body.0.dau_top.gcnet.channel_add_conv.2.weight[FLOAT, 80x80x1x1]
#   %body.1.body.0.dau_mid.body.0.weight[FLOAT, 120x60x3x3]
#   %body.1.body.0.dau_mid.body.2.weight[FLOAT, 120x60x3x3]
#   %body.1.body.0.dau_mid.gcnet.conv_mask.weight[FLOAT, 1x120x1x1]
#   %body.1.body.0.dau_mid.gcnet.channel_add_conv.0.weight[FLOAT, 120x120x1x1]
#   %body.1.body.0.dau_mid.gcnet.channel_add_conv.2.weight[FLOAT, 120x120x1x1]
#   %body.1.body.0.dau_bot.body.0.weight[FLOAT, 180x90x3x3]
#   %body.1.body.0.dau_bot.body.2.weight[FLOAT, 180x90x3x3]
#   %body.1.body.0.dau_bot.gcnet.conv_mask.weight[FLOAT, 1x180x1x1]
#   %body.1.body.0.dau_bot.gcnet.channel_add_conv.0.weight[FLOAT, 180x180x1x1]
#   %body.1.body.0.dau_bot.gcnet.channel_add_conv.2.weight[FLOAT, 180x180x1x1]
#   %body.1.body.0.down2.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.1.body.0.down4.0.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.1.body.0.down4.1.body.0.bot.1.weight[FLOAT, 180x120x1x1]
#   %body.1.body.0.up21_1.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.1.body.0.up21_2.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.1.body.0.up32_1.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.1.body.0.up32_2.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.1.body.0.conv_out.weight[FLOAT, 80x80x1x1]
#   %body.1.body.0.skff_top.conv_du.0.weight[FLOAT, 10x80x1x1]
#   %body.1.body.0.skff_top.fcs.0.weight[FLOAT, 80x10x1x1]
#   %body.1.body.0.skff_top.fcs.1.weight[FLOAT, 80x10x1x1]
#   %body.1.body.0.skff_mid.conv_du.0.weight[FLOAT, 15x120x1x1]
#   %body.1.body.0.skff_mid.fcs.0.weight[FLOAT, 120x15x1x1]
#   %body.1.body.0.skff_mid.fcs.1.weight[FLOAT, 120x15x1x1]
#   %body.1.body.1.dau_top.body.0.weight[FLOAT, 80x40x3x3]
#   %body.1.body.1.dau_top.body.2.weight[FLOAT, 80x40x3x3]
#   %body.1.body.1.dau_top.gcnet.conv_mask.weight[FLOAT, 1x80x1x1]
#   %body.1.body.1.dau_top.gcnet.channel_add_conv.0.weight[FLOAT, 80x80x1x1]
#   %body.1.body.1.dau_top.gcnet.channel_add_conv.2.weight[FLOAT, 80x80x1x1]
#   %body.1.body.1.dau_mid.body.0.weight[FLOAT, 120x60x3x3]
#   %body.1.body.1.dau_mid.body.2.weight[FLOAT, 120x60x3x3]
#   %body.1.body.1.dau_mid.gcnet.conv_mask.weight[FLOAT, 1x120x1x1]
#   %body.1.body.1.dau_mid.gcnet.channel_add_conv.0.weight[FLOAT, 120x120x1x1]
#   %body.1.body.1.dau_mid.gcnet.channel_add_conv.2.weight[FLOAT, 120x120x1x1]
#   %body.1.body.1.dau_bot.body.0.weight[FLOAT, 180x90x3x3]
#   %body.1.body.1.dau_bot.body.2.weight[FLOAT, 180x90x3x3]
#   %body.1.body.1.dau_bot.gcnet.conv_mask.weight[FLOAT, 1x180x1x1]
#   %body.1.body.1.dau_bot.gcnet.channel_add_conv.0.weight[FLOAT, 180x180x1x1]
#   %body.1.body.1.dau_bot.gcnet.channel_add_conv.2.weight[FLOAT, 180x180x1x1]
#   %body.1.body.1.down2.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.1.body.1.down4.0.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.1.body.1.down4.1.body.0.bot.1.weight[FLOAT, 180x120x1x1]
#   %body.1.body.1.up21_1.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.1.body.1.up21_2.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.1.body.1.up32_1.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.1.body.1.up32_2.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.1.body.1.conv_out.weight[FLOAT, 80x80x1x1]
#   %body.1.body.1.skff_top.conv_du.0.weight[FLOAT, 10x80x1x1]
#   %body.1.body.1.skff_top.fcs.0.weight[FLOAT, 80x10x1x1]
#   %body.1.body.1.skff_top.fcs.1.weight[FLOAT, 80x10x1x1]
#   %body.1.body.1.skff_mid.conv_du.0.weight[FLOAT, 15x120x1x1]
#   %body.1.body.1.skff_mid.fcs.0.weight[FLOAT, 120x15x1x1]
#   %body.1.body.1.skff_mid.fcs.1.weight[FLOAT, 120x15x1x1]
#   %body.1.body.2.weight[FLOAT, 80x80x3x3]
#   %body.2.body.0.dau_top.body.0.weight[FLOAT, 80x20x3x3]
#   %body.2.body.0.dau_top.body.2.weight[FLOAT, 80x20x3x3]
#   %body.2.body.0.dau_top.gcnet.conv_mask.weight[FLOAT, 1x80x1x1]
#   %body.2.body.0.dau_top.gcnet.channel_add_conv.0.weight[FLOAT, 80x80x1x1]
#   %body.2.body.0.dau_top.gcnet.channel_add_conv.2.weight[FLOAT, 80x80x1x1]
#   %body.2.body.0.dau_mid.body.0.weight[FLOAT, 120x30x3x3]
#   %body.2.body.0.dau_mid.body.2.weight[FLOAT, 120x30x3x3]
#   %body.2.body.0.dau_mid.gcnet.conv_mask.weight[FLOAT, 1x120x1x1]
#   %body.2.body.0.dau_mid.gcnet.channel_add_conv.0.weight[FLOAT, 120x120x1x1]
#   %body.2.body.0.dau_mid.gcnet.channel_add_conv.2.weight[FLOAT, 120x120x1x1]
#   %body.2.body.0.dau_bot.body.0.weight[FLOAT, 180x45x3x3]
#   %body.2.body.0.dau_bot.body.2.weight[FLOAT, 180x45x3x3]
#   %body.2.body.0.dau_bot.gcnet.conv_mask.weight[FLOAT, 1x180x1x1]
#   %body.2.body.0.dau_bot.gcnet.channel_add_conv.0.weight[FLOAT, 180x180x1x1]
#   %body.2.body.0.dau_bot.gcnet.channel_add_conv.2.weight[FLOAT, 180x180x1x1]
#   %body.2.body.0.down2.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.2.body.0.down4.0.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.2.body.0.down4.1.body.0.bot.1.weight[FLOAT, 180x120x1x1]
#   %body.2.body.0.up21_1.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.2.body.0.up21_2.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.2.body.0.up32_1.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.2.body.0.up32_2.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.2.body.0.conv_out.weight[FLOAT, 80x80x1x1]
#   %body.2.body.0.skff_top.conv_du.0.weight[FLOAT, 10x80x1x1]
#   %body.2.body.0.skff_top.fcs.0.weight[FLOAT, 80x10x1x1]
#   %body.2.body.0.skff_top.fcs.1.weight[FLOAT, 80x10x1x1]
#   %body.2.body.0.skff_mid.conv_du.0.weight[FLOAT, 15x120x1x1]
#   %body.2.body.0.skff_mid.fcs.0.weight[FLOAT, 120x15x1x1]
#   %body.2.body.0.skff_mid.fcs.1.weight[FLOAT, 120x15x1x1]
#   %body.2.body.1.dau_top.body.0.weight[FLOAT, 80x20x3x3]
#   %body.2.body.1.dau_top.body.2.weight[FLOAT, 80x20x3x3]
#   %body.2.body.1.dau_top.gcnet.conv_mask.weight[FLOAT, 1x80x1x1]
#   %body.2.body.1.dau_top.gcnet.channel_add_conv.0.weight[FLOAT, 80x80x1x1]
#   %body.2.body.1.dau_top.gcnet.channel_add_conv.2.weight[FLOAT, 80x80x1x1]
#   %body.2.body.1.dau_mid.body.0.weight[FLOAT, 120x30x3x3]
#   %body.2.body.1.dau_mid.body.2.weight[FLOAT, 120x30x3x3]
#   %body.2.body.1.dau_mid.gcnet.conv_mask.weight[FLOAT, 1x120x1x1]
#   %body.2.body.1.dau_mid.gcnet.channel_add_conv.0.weight[FLOAT, 120x120x1x1]
#   %body.2.body.1.dau_mid.gcnet.channel_add_conv.2.weight[FLOAT, 120x120x1x1]
#   %body.2.body.1.dau_bot.body.0.weight[FLOAT, 180x45x3x3]
#   %body.2.body.1.dau_bot.body.2.weight[FLOAT, 180x45x3x3]
#   %body.2.body.1.dau_bot.gcnet.conv_mask.weight[FLOAT, 1x180x1x1]
#   %body.2.body.1.dau_bot.gcnet.channel_add_conv.0.weight[FLOAT, 180x180x1x1]
#   %body.2.body.1.dau_bot.gcnet.channel_add_conv.2.weight[FLOAT, 180x180x1x1]
#   %body.2.body.1.down2.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.2.body.1.down4.0.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.2.body.1.down4.1.body.0.bot.1.weight[FLOAT, 180x120x1x1]
#   %body.2.body.1.up21_1.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.2.body.1.up21_2.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.2.body.1.up32_1.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.2.body.1.up32_2.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.2.body.1.conv_out.weight[FLOAT, 80x80x1x1]
#   %body.2.body.1.skff_top.conv_du.0.weight[FLOAT, 10x80x1x1]
#   %body.2.body.1.skff_top.fcs.0.weight[FLOAT, 80x10x1x1]
#   %body.2.body.1.skff_top.fcs.1.weight[FLOAT, 80x10x1x1]
#   %body.2.body.1.skff_mid.conv_du.0.weight[FLOAT, 15x120x1x1]
#   %body.2.body.1.skff_mid.fcs.0.weight[FLOAT, 120x15x1x1]
#   %body.2.body.1.skff_mid.fcs.1.weight[FLOAT, 120x15x1x1]
#   %body.2.body.2.weight[FLOAT, 80x80x3x3]
#   %body.3.body.0.dau_top.body.0.weight[FLOAT, 80x20x3x3]
#   %body.3.body.0.dau_top.body.2.weight[FLOAT, 80x20x3x3]
#   %body.3.body.0.dau_top.gcnet.conv_mask.weight[FLOAT, 1x80x1x1]
#   %body.3.body.0.dau_top.gcnet.channel_add_conv.0.weight[FLOAT, 80x80x1x1]
#   %body.3.body.0.dau_top.gcnet.channel_add_conv.2.weight[FLOAT, 80x80x1x1]
#   %body.3.body.0.dau_mid.body.0.weight[FLOAT, 120x30x3x3]
#   %body.3.body.0.dau_mid.body.2.weight[FLOAT, 120x30x3x3]
#   %body.3.body.0.dau_mid.gcnet.conv_mask.weight[FLOAT, 1x120x1x1]
#   %body.3.body.0.dau_mid.gcnet.channel_add_conv.0.weight[FLOAT, 120x120x1x1]
#   %body.3.body.0.dau_mid.gcnet.channel_add_conv.2.weight[FLOAT, 120x120x1x1]
#   %body.3.body.0.dau_bot.body.0.weight[FLOAT, 180x45x3x3]
#   %body.3.body.0.dau_bot.body.2.weight[FLOAT, 180x45x3x3]
#   %body.3.body.0.dau_bot.gcnet.conv_mask.weight[FLOAT, 1x180x1x1]
#   %body.3.body.0.dau_bot.gcnet.channel_add_conv.0.weight[FLOAT, 180x180x1x1]
#   %body.3.body.0.dau_bot.gcnet.channel_add_conv.2.weight[FLOAT, 180x180x1x1]
#   %body.3.body.0.down2.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.3.body.0.down4.0.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.3.body.0.down4.1.body.0.bot.1.weight[FLOAT, 180x120x1x1]
#   %body.3.body.0.up21_1.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.3.body.0.up21_2.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.3.body.0.up32_1.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.3.body.0.up32_2.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.3.body.0.conv_out.weight[FLOAT, 80x80x1x1]
#   %body.3.body.0.skff_top.conv_du.0.weight[FLOAT, 10x80x1x1]
#   %body.3.body.0.skff_top.fcs.0.weight[FLOAT, 80x10x1x1]
#   %body.3.body.0.skff_top.fcs.1.weight[FLOAT, 80x10x1x1]
#   %body.3.body.0.skff_mid.conv_du.0.weight[FLOAT, 15x120x1x1]
#   %body.3.body.0.skff_mid.fcs.0.weight[FLOAT, 120x15x1x1]
#   %body.3.body.0.skff_mid.fcs.1.weight[FLOAT, 120x15x1x1]
#   %body.3.body.1.dau_top.body.0.weight[FLOAT, 80x20x3x3]
#   %body.3.body.1.dau_top.body.2.weight[FLOAT, 80x20x3x3]
#   %body.3.body.1.dau_top.gcnet.conv_mask.weight[FLOAT, 1x80x1x1]
#   %body.3.body.1.dau_top.gcnet.channel_add_conv.0.weight[FLOAT, 80x80x1x1]
#   %body.3.body.1.dau_top.gcnet.channel_add_conv.2.weight[FLOAT, 80x80x1x1]
#   %body.3.body.1.dau_mid.body.0.weight[FLOAT, 120x30x3x3]
#   %body.3.body.1.dau_mid.body.2.weight[FLOAT, 120x30x3x3]
#   %body.3.body.1.dau_mid.gcnet.conv_mask.weight[FLOAT, 1x120x1x1]
#   %body.3.body.1.dau_mid.gcnet.channel_add_conv.0.weight[FLOAT, 120x120x1x1]
#   %body.3.body.1.dau_mid.gcnet.channel_add_conv.2.weight[FLOAT, 120x120x1x1]
#   %body.3.body.1.dau_bot.body.0.weight[FLOAT, 180x45x3x3]
#   %body.3.body.1.dau_bot.body.2.weight[FLOAT, 180x45x3x3]
#   %body.3.body.1.dau_bot.gcnet.conv_mask.weight[FLOAT, 1x180x1x1]
#   %body.3.body.1.dau_bot.gcnet.channel_add_conv.0.weight[FLOAT, 180x180x1x1]
#   %body.3.body.1.dau_bot.gcnet.channel_add_conv.2.weight[FLOAT, 180x180x1x1]
#   %body.3.body.1.down2.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.3.body.1.down4.0.body.0.bot.1.weight[FLOAT, 120x80x1x1]
#   %body.3.body.1.down4.1.body.0.bot.1.weight[FLOAT, 180x120x1x1]
#   %body.3.body.1.up21_1.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.3.body.1.up21_2.body.0.bot.0.weight[FLOAT, 80x120x1x1]
#   %body.3.body.1.up32_1.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.3.body.1.up32_2.body.0.bot.0.weight[FLOAT, 120x180x1x1]
#   %body.3.body.1.conv_out.weight[FLOAT, 80x80x1x1]
#   %body.3.body.1.skff_top.conv_du.0.weight[FLOAT, 10x80x1x1]
#   %body.3.body.1.skff_top.fcs.0.weight[FLOAT, 80x10x1x1]
#   %body.3.body.1.skff_top.fcs.1.weight[FLOAT, 80x10x1x1]
#   %body.3.body.1.skff_mid.conv_du.0.weight[FLOAT, 15x120x1x1]
#   %body.3.body.1.skff_mid.fcs.0.weight[FLOAT, 120x15x1x1]
#   %body.3.body.1.skff_mid.fcs.1.weight[FLOAT, 120x15x1x1]
#   %body.3.body.2.weight[FLOAT, 80x80x3x3]
#   %conv_out.weight[FLOAT, 3x80x3x3]
# ) {
#   %/conv_in/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/conv_in/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%input, %conv_in.weight)
#   %/body/body.0/body/body.0/down2/body/body.0/bot/bot.0/AveragePool_output_0 = AveragePool[kernel_shape = [2, 2], pads = [0, 0, 1, 1], strides = [2, 2]](%/conv_in/Conv_output_0)
#   %/body/body.0/body/body.0/down2/body/body.0/bot/bot.1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/down2/body/body.0/bot/bot.0/AveragePool_output_0, %body.0.body.0.down2.body.0.bot.1.weight)
#   %/body/body.0/body/body.0/down4/down4.0/body/body.0/bot/bot.1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/down2/body/body.0/bot/bot.0/AveragePool_output_0, %body.0.body.0.down4.0.body.0.bot.1.weight)
#   %/body/body.0/body/body.0/down4/down4.1/body/body.0/bot/bot.0/AveragePool_output_0 = AveragePool[kernel_shape = [2, 2], pads = [0, 0, 1, 1], strides = [2, 2]](%/body/body.0/body/body.0/down4/down4.0/body/body.0/bot/bot.1/Conv_output_0)
#   %/body/body.0/body/body.0/down4/down4.1/body/body.0/bot/bot.1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/down4/down4.1/body/body.0/bot/bot.0/AveragePool_output_0, %body.0.body.0.down4.1.body.0.bot.1.weight)
#   %/body/body.0/body/body.0/dau_top/body/body.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/conv_in/Conv_output_0, %body.0.body.0.dau_top.body.0.weight)
#   %/body/body.0/body/body.0/dau_top/body/body.1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.0/body/body.0/dau_top/body/body.0/Conv_output_0)
#   %/body/body.0/body/body.0/dau_top/body/body.2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/body/body.0/body/body.0/dau_top/body/body.1/LeakyRelu_output_0, %body.0.body.0.dau_top.body.2.weight)
#   %/body/body.0/body/body.0/dau_top/gcnet/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Shape_output_0 = Shape(%/body/body.0/body/body.0/dau_top/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Gather_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_top/gcnet/Shape_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Constant_1_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Shape_1_output_0 = Shape(%/body/body.0/body/body.0/dau_top/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Constant_2_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Gather_1_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_top/gcnet/Shape_1_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Constant_2_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Shape_2_output_0 = Shape(%/body/body.0/body/body.0/dau_top/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Constant_3_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Gather_2_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_top/gcnet/Shape_2_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Constant_3_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Shape_3_output_0 = Shape(%/body/body.0/body/body.0/dau_top/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Constant_4_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Gather_3_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_top/gcnet/Shape_3_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Constant_4_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Mul_output_0 = Mul(%/body/body.0/body/body.0/dau_top/gcnet/Gather_2_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Gather_3_output_0)
#   %onnx::Unsqueeze_264 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_top/gcnet/Gather_output_0, %onnx::Unsqueeze_264)
#   %onnx::Unsqueeze_266 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_1_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_top/gcnet/Gather_1_output_0, %onnx::Unsqueeze_266)
#   %onnx::Unsqueeze_268 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_2_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_top/gcnet/Mul_output_0, %onnx::Unsqueeze_268)
#   %/body/body.0/body/body.0/dau_top/gcnet/Concat_output_0 = Concat[axis = 0](%/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_1_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_2_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Reshape_output_0 = Reshape(%/body/body.0/body/body.0/dau_top/body/body.2/Conv_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Concat_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Constant_5_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_3_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_top/gcnet/Reshape_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Constant_5_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/conv_mask/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/dau_top/body/body.2/Conv_output_0, %body.0.body.0.dau_top.gcnet.conv_mask.weight)
#   %onnx::Unsqueeze_275 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_4_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_top/gcnet/Gather_output_0, %onnx::Unsqueeze_275)
#   %/body/body.0/body/body.0/dau_top/gcnet/Constant_6_output_0 = Constant[value = <Tensor>]()
#   %onnx::Unsqueeze_279 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_5_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_top/gcnet/Mul_output_0, %onnx::Unsqueeze_279)
#   %/body/body.0/body/body.0/dau_top/gcnet/Concat_1_output_0 = Concat[axis = 0](%/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_4_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Constant_6_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_5_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Reshape_1_output_0 = Reshape(%/body/body.0/body/body.0/dau_top/gcnet/conv_mask/Conv_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Concat_1_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/softmax/Softmax_output_0 = Softmax[axis = -1](%/body/body.0/body/body.0/dau_top/gcnet/Reshape_1_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Constant_7_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_6_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_top/gcnet/softmax/Softmax_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Constant_7_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/MatMul_output_0 = MatMul(%/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_3_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_6_output_0)
#   %onnx::Unsqueeze_287 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_7_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_top/gcnet/Gather_output_0, %onnx::Unsqueeze_287)
#   %onnx::Unsqueeze_289 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_8_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_top/gcnet/Gather_1_output_0, %onnx::Unsqueeze_289)
#   %/body/body.0/body/body.0/dau_top/gcnet/Constant_8_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Constant_9_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_top/gcnet/Concat_2_output_0 = Concat[axis = 0](%/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_7_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Unsqueeze_8_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Constant_8_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Constant_9_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/Reshape_2_output_0 = Reshape(%/body/body.0/body/body.0/dau_top/gcnet/MatMul_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Concat_2_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/channel_add_conv/channel_add_conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/dau_top/gcnet/Reshape_2_output_0, %body.0.body.0.dau_top.gcnet.channel_add_conv.0.weight)
#   %/body/body.0/body/body.0/dau_top/gcnet/channel_add_conv/channel_add_conv.1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.0/body/body.0/dau_top/gcnet/channel_add_conv/channel_add_conv.0/Conv_output_0)
#   %/body/body.0/body/body.0/dau_top/gcnet/channel_add_conv/channel_add_conv.2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/dau_top/gcnet/channel_add_conv/channel_add_conv.1/LeakyRelu_output_0, %body.0.body.0.dau_top.gcnet.channel_add_conv.2.weight)
#   %/body/body.0/body/body.0/dau_top/gcnet/Add_output_0 = Add(%/body/body.0/body/body.0/dau_top/body/body.2/Conv_output_0, %/body/body.0/body/body.0/dau_top/gcnet/channel_add_conv/channel_add_conv.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_top/body.1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.0/body/body.0/dau_top/gcnet/Add_output_0)
#   %/body/body.0/body/body.0/dau_top/Add_output_0 = Add(%/body/body.0/body/body.0/dau_top/body.1/LeakyRelu_output_0, %/conv_in/Conv_output_0)
#   %/body/body.0/body/body.0/dau_mid/body/body.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/body/body.0/body/body.0/down2/body/body.0/bot/bot.1/Conv_output_0, %body.0.body.0.dau_mid.body.0.weight)
#   %/body/body.0/body/body.0/dau_mid/body/body.1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.0/body/body.0/dau_mid/body/body.0/Conv_output_0)
#   %/body/body.0/body/body.0/dau_mid/body/body.2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/body/body.0/body/body.0/dau_mid/body/body.1/LeakyRelu_output_0, %body.0.body.0.dau_mid.body.2.weight)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Shape_output_0 = Shape(%/body/body.0/body/body.0/dau_mid/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Gather_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_mid/gcnet/Shape_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Constant_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Shape_1_output_0 = Shape(%/body/body.0/body/body.0/dau_mid/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Gather_1_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_mid/gcnet/Shape_1_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Constant_1_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Shape_2_output_0 = Shape(%/body/body.0/body/body.0/dau_mid/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Constant_2_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Gather_2_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_mid/gcnet/Shape_2_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Constant_2_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Shape_3_output_0 = Shape(%/body/body.0/body/body.0/dau_mid/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Constant_3_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Gather_3_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_mid/gcnet/Shape_3_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Constant_3_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Mul_output_0 = Mul(%/body/body.0/body/body.0/dau_mid/gcnet/Gather_2_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Gather_3_output_0)
#   %onnx::Unsqueeze_319 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_mid/gcnet/Gather_output_0, %onnx::Unsqueeze_319)
#   %onnx::Unsqueeze_321 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_1_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_mid/gcnet/Gather_1_output_0, %onnx::Unsqueeze_321)
#   %onnx::Unsqueeze_323 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_2_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_mid/gcnet/Mul_output_0, %onnx::Unsqueeze_323)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Concat_output_0 = Concat[axis = 0](%/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_1_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_2_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Reshape_output_0 = Reshape(%/body/body.0/body/body.0/dau_mid/body/body.2/Conv_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Concat_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Constant_4_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_3_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_mid/gcnet/Reshape_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Constant_4_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/conv_mask/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/dau_mid/body/body.2/Conv_output_0, %body.0.body.0.dau_mid.gcnet.conv_mask.weight)
#   %onnx::Unsqueeze_330 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_4_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_mid/gcnet/Gather_output_0, %onnx::Unsqueeze_330)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Constant_5_output_0 = Constant[value = <Tensor>]()
#   %onnx::Unsqueeze_334 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_5_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_mid/gcnet/Mul_output_0, %onnx::Unsqueeze_334)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Concat_1_output_0 = Concat[axis = 0](%/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_4_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Constant_5_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_5_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Reshape_1_output_0 = Reshape(%/body/body.0/body/body.0/dau_mid/gcnet/conv_mask/Conv_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Concat_1_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/softmax/Softmax_output_0 = Softmax[axis = -1](%/body/body.0/body/body.0/dau_mid/gcnet/Reshape_1_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Constant_6_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_6_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_mid/gcnet/softmax/Softmax_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Constant_6_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/MatMul_output_0 = MatMul(%/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_3_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_6_output_0)
#   %onnx::Unsqueeze_342 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_7_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_mid/gcnet/Gather_output_0, %onnx::Unsqueeze_342)
#   %onnx::Unsqueeze_344 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_8_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_mid/gcnet/Gather_1_output_0, %onnx::Unsqueeze_344)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Constant_7_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Constant_8_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_mid/gcnet/Concat_2_output_0 = Concat[axis = 0](%/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_7_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Unsqueeze_8_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Constant_7_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Constant_8_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Reshape_2_output_0 = Reshape(%/body/body.0/body/body.0/dau_mid/gcnet/MatMul_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/Concat_2_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/channel_add_conv/channel_add_conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/dau_mid/gcnet/Reshape_2_output_0, %body.0.body.0.dau_mid.gcnet.channel_add_conv.0.weight)
#   %/body/body.0/body/body.0/dau_mid/gcnet/channel_add_conv/channel_add_conv.1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.0/body/body.0/dau_mid/gcnet/channel_add_conv/channel_add_conv.0/Conv_output_0)
#   %/body/body.0/body/body.0/dau_mid/gcnet/channel_add_conv/channel_add_conv.2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/dau_mid/gcnet/channel_add_conv/channel_add_conv.1/LeakyRelu_output_0, %body.0.body.0.dau_mid.gcnet.channel_add_conv.2.weight)
#   %/body/body.0/body/body.0/dau_mid/gcnet/Add_output_0 = Add(%/body/body.0/body/body.0/dau_mid/body/body.2/Conv_output_0, %/body/body.0/body/body.0/dau_mid/gcnet/channel_add_conv/channel_add_conv.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_mid/body.1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.0/body/body.0/dau_mid/gcnet/Add_output_0)
#   %/body/body.0/body/body.0/dau_mid/Add_output_0 = Add(%/body/body.0/body/body.0/dau_mid/body.1/LeakyRelu_output_0, %/body/body.0/body/body.0/down2/body/body.0/bot/bot.1/Conv_output_0)
#   %/body/body.0/body/body.0/dau_bot/body/body.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/body/body.0/body/body.0/down4/down4.1/body/body.0/bot/bot.1/Conv_output_0, %body.0.body.0.dau_bot.body.0.weight)
#   %/body/body.0/body/body.0/dau_bot/body/body.1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.0/body/body.0/dau_bot/body/body.0/Conv_output_0)
#   %/body/body.0/body/body.0/dau_bot/body/body.2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/body/body.0/body/body.0/dau_bot/body/body.1/LeakyRelu_output_0, %body.0.body.0.dau_bot.body.2.weight)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Shape_output_0 = Shape(%/body/body.0/body/body.0/dau_bot/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Gather_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_bot/gcnet/Shape_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Constant_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Shape_1_output_0 = Shape(%/body/body.0/body/body.0/dau_bot/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Gather_1_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_bot/gcnet/Shape_1_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Constant_1_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Shape_2_output_0 = Shape(%/body/body.0/body/body.0/dau_bot/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Constant_2_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Gather_2_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_bot/gcnet/Shape_2_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Constant_2_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Shape_3_output_0 = Shape(%/body/body.0/body/body.0/dau_bot/body/body.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Constant_3_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Gather_3_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/dau_bot/gcnet/Shape_3_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Constant_3_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Mul_output_0 = Mul(%/body/body.0/body/body.0/dau_bot/gcnet/Gather_2_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Gather_3_output_0)
#   %onnx::Unsqueeze_374 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_bot/gcnet/Gather_output_0, %onnx::Unsqueeze_374)
#   %onnx::Unsqueeze_376 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_1_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_bot/gcnet/Gather_1_output_0, %onnx::Unsqueeze_376)
#   %onnx::Unsqueeze_378 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_2_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_bot/gcnet/Mul_output_0, %onnx::Unsqueeze_378)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Concat_output_0 = Concat[axis = 0](%/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_1_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_2_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Reshape_output_0 = Reshape(%/body/body.0/body/body.0/dau_bot/body/body.2/Conv_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Concat_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Constant_4_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_3_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_bot/gcnet/Reshape_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Constant_4_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/conv_mask/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/dau_bot/body/body.2/Conv_output_0, %body.0.body.0.dau_bot.gcnet.conv_mask.weight)
#   %onnx::Unsqueeze_385 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_4_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_bot/gcnet/Gather_output_0, %onnx::Unsqueeze_385)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Constant_5_output_0 = Constant[value = <Tensor>]()
#   %onnx::Unsqueeze_389 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_5_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_bot/gcnet/Mul_output_0, %onnx::Unsqueeze_389)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Concat_1_output_0 = Concat[axis = 0](%/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_4_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Constant_5_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_5_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Reshape_1_output_0 = Reshape(%/body/body.0/body/body.0/dau_bot/gcnet/conv_mask/Conv_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Concat_1_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/softmax/Softmax_output_0 = Softmax[axis = -1](%/body/body.0/body/body.0/dau_bot/gcnet/Reshape_1_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Constant_6_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_6_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_bot/gcnet/softmax/Softmax_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Constant_6_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/MatMul_output_0 = MatMul(%/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_3_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_6_output_0)
#   %onnx::Unsqueeze_397 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_7_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_bot/gcnet/Gather_output_0, %onnx::Unsqueeze_397)
#   %onnx::Unsqueeze_399 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_8_output_0 = Unsqueeze(%/body/body.0/body/body.0/dau_bot/gcnet/Gather_1_output_0, %onnx::Unsqueeze_399)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Constant_7_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Constant_8_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/dau_bot/gcnet/Concat_2_output_0 = Concat[axis = 0](%/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_7_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Unsqueeze_8_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Constant_7_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Constant_8_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Reshape_2_output_0 = Reshape(%/body/body.0/body/body.0/dau_bot/gcnet/MatMul_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/Concat_2_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/channel_add_conv/channel_add_conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/dau_bot/gcnet/Reshape_2_output_0, %body.0.body.0.dau_bot.gcnet.channel_add_conv.0.weight)
#   %/body/body.0/body/body.0/dau_bot/gcnet/channel_add_conv/channel_add_conv.1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.0/body/body.0/dau_bot/gcnet/channel_add_conv/channel_add_conv.0/Conv_output_0)
#   %/body/body.0/body/body.0/dau_bot/gcnet/channel_add_conv/channel_add_conv.2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/dau_bot/gcnet/channel_add_conv/channel_add_conv.1/LeakyRelu_output_0, %body.0.body.0.dau_bot.gcnet.channel_add_conv.2.weight)
#   %/body/body.0/body/body.0/dau_bot/gcnet/Add_output_0 = Add(%/body/body.0/body/body.0/dau_bot/body/body.2/Conv_output_0, %/body/body.0/body/body.0/dau_bot/gcnet/channel_add_conv/channel_add_conv.2/Conv_output_0)
#   %/body/body.0/body/body.0/dau_bot/body.1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.0/body/body.0/dau_bot/gcnet/Add_output_0)
#   %/body/body.0/body/body.0/dau_bot/Add_output_0 = Add(%/body/body.0/body/body.0/dau_bot/body.1/LeakyRelu_output_0, %/body/body.0/body/body.0/down4/down4.1/body/body.0/bot/bot.1/Conv_output_0)
#   %/body/body.0/body/body.0/up32_1/body/body.0/bot/bot.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/dau_bot/Add_output_0, %body.0.body.0.up32_1.body.0.bot.0.weight)
#   %/body/body.0/body/body.0/up32_1/body/body.0/bot/bot.1/Constant_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/up32_1/body/body.0/bot/bot.1/Resize_output_0 = Resize[coordinate_transformation_mode = 'half_pixel', cubic_coeff_a = -0.75, mode = 'linear', nearest_mode = 'floor'](%/body/body.0/body/body.0/up32_1/body/body.0/bot/bot.0/Conv_output_0, %, %/body/body.0/body/body.0/up32_1/body/body.0/bot/bot.1/Constant_output_0)
#   %/body/body.0/body/body.0/skff_mid/Shape_output_0 = Shape(%/body/body.0/body/body.0/dau_mid/Add_output_0)
#   %/body/body.0/body/body.0/skff_mid/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/skff_mid/Gather_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/skff_mid/Shape_output_0, %/body/body.0/body/body.0/skff_mid/Constant_output_0)
#   %/body/body.0/body/body.0/skff_mid/Shape_1_output_0 = Shape(%/body/body.0/body/body.0/dau_mid/Add_output_0)
#   %/body/body.0/body/body.0/skff_mid/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/skff_mid/Gather_1_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/skff_mid/Shape_1_output_0, %/body/body.0/body/body.0/skff_mid/Constant_1_output_0)
#   %/body/body.0/body/body.0/skff_mid/Concat_output_0 = Concat[axis = 1](%/body/body.0/body/body.0/dau_mid/Add_output_0, %/body/body.0/body/body.0/up32_1/body/body.0/bot/bot.1/Resize_output_0)
#   %/body/body.0/body/body.0/skff_mid/Shape_2_output_0 = Shape(%/body/body.0/body/body.0/skff_mid/Concat_output_0)
#   %/body/body.0/body/body.0/skff_mid/Constant_2_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/skff_mid/Gather_2_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/skff_mid/Shape_2_output_0, %/body/body.0/body/body.0/skff_mid/Constant_2_output_0)
#   %/body/body.0/body/body.0/skff_mid/Shape_3_output_0 = Shape(%/body/body.0/body/body.0/skff_mid/Concat_output_0)
#   %/body/body.0/body/body.0/skff_mid/Constant_3_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.0/body/body.0/skff_mid/Gather_3_output_0 = Gather[axis = 0](%/body/body.0/body/body.0/skff_mid/Shape_3_output_0, %/body/body.0/body/body.0/skff_mid/Constant_3_output_0)
#   %onnx::Unsqueeze_432 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/skff_mid/Unsqueeze_output_0 = Unsqueeze(%/body/body.0/body/body.0/skff_mid/Gather_output_0, %onnx::Unsqueeze_432)
#   %/body/body.0/body/body.0/skff_mid/Constant_4_output_0 = Constant[value = <Tensor>]()
#   %onnx::Unsqueeze_436 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/skff_mid/Unsqueeze_1_output_0 = Unsqueeze(%/body/body.0/body/body.0/skff_mid/Gather_1_output_0, %onnx::Unsqueeze_436)
#   %onnx::Unsqueeze_438 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/skff_mid/Unsqueeze_2_output_0 = Unsqueeze(%/body/body.0/body/body.0/skff_mid/Gather_2_output_0, %onnx::Unsqueeze_438)
#   %onnx::Unsqueeze_440 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/skff_mid/Unsqueeze_3_output_0 = Unsqueeze(%/body/body.0/body/body.0/skff_mid/Gather_3_output_0, %onnx::Unsqueeze_440)
#   %/body/body.0/body/body.0/skff_mid/Concat_1_output_0 = Concat[axis = 0](%/body/body.0/body/body.0/skff_mid/Unsqueeze_output_0, %/body/body.0/body/body.0/skff_mid/Constant_4_output_0, %/body/body.0/body/body.0/skff_mid/Unsqueeze_1_output_0, %/body/body.0/body/body.0/skff_mid/Unsqueeze_2_output_0, %/body/body.0/body/body.0/skff_mid/Unsqueeze_3_output_0)
#   %/body/body.0/body/body.0/skff_mid/Reshape_output_0 = Reshape(%/body/body.0/body/body.0/skff_mid/Concat_output_0, %/body/body.0/body/body.0/skff_mid/Concat_1_output_0)
#   %onnx::ReduceSum_444 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/skff_mid/ReduceSum_output_0 = ReduceSum[keepdims = 0](%/body/body.0/body/body.0/skff_mid/Reshape_output_0, %onnx::ReduceSum_444)
#   %/body/body.0/body/body.0/skff_mid/avg_pool/GlobalAveragePool_output_0 = GlobalAveragePool(%/body/body.0/body/body.0/skff_mid/ReduceSum_output_0)
#   %/body/body.0/body/body.0/skff_mid/conv_du/conv_du.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/skff_mid/avg_pool/GlobalAveragePool_output_0, %body.0.body.0.skff_mid.conv_du.0.weight)
#   %/body/body.0/body/body.0/skff_mid/conv_du/conv_du.1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.0/body/body.0/skff_mid/conv_du/conv_du.0/Conv_output_0)
#   %/body/body.0/body/body.0/skff_mid/fcs.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/skff_mid/conv_du/conv_du.1/LeakyRelu_output_0, %body.0.body.0.skff_mid.fcs.0.weight)
#   %/body/body.0/body/body.0/skff_mid/fcs.1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.0/body/body.0/skff_mid/conv_du/conv_du.1/LeakyRelu_output_0, %body.0.body.0.skff_mid.fcs.1.weight)
#   %/body/body.0/body/body.0/skff_mid/Concat_2_output_0 = Concat[axis = 1](%/body/body.0/body/body.0/skff_mid/fcs.0/Conv_output_0, %/body/body.0/body/body.0/skff_mid/fcs.1/Conv_output_0)
#   %onnx::Unsqueeze_452 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/skff_mid/Unsqueeze_4_output_0 = Unsqueeze(%/body/body.0/body/body.0/skff_mid/Gather_output_0, %onnx::Unsqueeze_452)
#   %/body/body.0/body/body.0/skff_mid/Constant_5_output_0 = Constant[value = <Tensor>]()
#   %onnx::Unsqueeze_456 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/skff_mid/Unsqueeze_5_output_0 = Unsqueeze(%/body/body.0/body/body.0/skff_mid/Gather_1_output_0, %onnx::Unsqueeze_456)
#   %/body/body.0/body/body.0/skff_mid/Constant_6_output_0 = Constant[value = <Tensor>]()
#   %/body/body.0/body/body.0/skff_mid/Constant_7_output_0 = Constant[value = <Tensor>]()
# ...
#   %/body/body.3/body/body.1/skff_mid_1/Shape_3_output_0 = Shape(%/body/body.3/body/body.1/skff_mid_1/Concat_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Constant_3_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.3/body/body.1/skff_mid_1/Gather_3_output_0 = Gather[axis = 0](%/body/body.3/body/body.1/skff_mid_1/Shape_3_output_0, %/body/body.3/body/body.1/skff_mid_1/Constant_3_output_0)
#   %onnx::Unsqueeze_4823 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_mid_1/Gather_output_0, %onnx::Unsqueeze_4823)
#   %/body/body.3/body/body.1/skff_mid_1/Constant_4_output_0 = Constant[value = <Tensor>]()
#   %onnx::Unsqueeze_4827 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_1_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_mid_1/Gather_1_output_0, %onnx::Unsqueeze_4827)
#   %onnx::Unsqueeze_4829 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_2_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_mid_1/Gather_2_output_0, %onnx::Unsqueeze_4829)
#   %onnx::Unsqueeze_4831 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_3_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_mid_1/Gather_3_output_0, %onnx::Unsqueeze_4831)
#   %/body/body.3/body/body.1/skff_mid_1/Concat_1_output_0 = Concat[axis = 0](%/body/body.3/body/body.1/skff_mid_1/Unsqueeze_output_0, %/body/body.3/body/body.1/skff_mid_1/Constant_4_output_0, %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_1_output_0, %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_2_output_0, %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_3_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Reshape_output_0 = Reshape(%/body/body.3/body/body.1/skff_mid_1/Concat_output_0, %/body/body.3/body/body.1/skff_mid_1/Concat_1_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/ReduceSum_output_0 = ReduceSum[keepdims = 0](%/body/body.3/body/body.1/skff_mid_1/Reshape_output_0, %onnx::ReduceSum_444)
#   %/body/body.3/body/body.1/skff_mid/avg_pool_1/GlobalAveragePool_output_0 = GlobalAveragePool(%/body/body.3/body/body.1/skff_mid_1/ReduceSum_output_0)
#   %/body/body.3/body/body.1/skff_mid/conv_du/conv_du.0_1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.3/body/body.1/skff_mid/avg_pool_1/GlobalAveragePool_output_0, %body.3.body.1.skff_mid.conv_du.0.weight)
#   %/body/body.3/body/body.1/skff_mid/conv_du/conv_du.1_1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.3/body/body.1/skff_mid/conv_du/conv_du.0_1/Conv_output_0)
#   %/body/body.3/body/body.1/skff_mid/fcs.0_1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.3/body/body.1/skff_mid/conv_du/conv_du.1_1/LeakyRelu_output_0, %body.3.body.1.skff_mid.fcs.0.weight)
#   %/body/body.3/body/body.1/skff_mid/fcs.1_1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.3/body/body.1/skff_mid/conv_du/conv_du.1_1/LeakyRelu_output_0, %body.3.body.1.skff_mid.fcs.1.weight)
#   %/body/body.3/body/body.1/skff_mid_1/Concat_2_output_0 = Concat[axis = 1](%/body/body.3/body/body.1/skff_mid/fcs.0_1/Conv_output_0, %/body/body.3/body/body.1/skff_mid/fcs.1_1/Conv_output_0)
#   %onnx::Unsqueeze_4842 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_4_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_mid_1/Gather_output_0, %onnx::Unsqueeze_4842)
#   %/body/body.3/body/body.1/skff_mid_1/Constant_5_output_0 = Constant[value = <Tensor>]()
#   %onnx::Unsqueeze_4846 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_5_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_mid_1/Gather_1_output_0, %onnx::Unsqueeze_4846)
#   %/body/body.3/body/body.1/skff_mid_1/Constant_6_output_0 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_mid_1/Constant_7_output_0 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_mid_1/Concat_3_output_0 = Concat[axis = 0](%/body/body.3/body/body.1/skff_mid_1/Unsqueeze_4_output_0, %/body/body.3/body/body.1/skff_mid_1/Constant_5_output_0, %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_5_output_0, %/body/body.3/body/body.1/skff_mid_1/Constant_6_output_0, %/body/body.3/body/body.1/skff_mid_1/Constant_7_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Reshape_1_output_0 = Reshape(%/body/body.3/body/body.1/skff_mid_1/Concat_2_output_0, %/body/body.3/body/body.1/skff_mid_1/Concat_3_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Exp_output_0 = Exp(%/body/body.3/body/body.1/skff_mid_1/Reshape_1_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Gather_4_output_0 = Gather[axis = 1](%/body/body.3/body/body.1/skff_mid_1/Reshape_1_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Constant_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Exp_1_output_0 = Exp(%/body/body.3/body/body.1/skff_mid_1/Gather_4_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Gather_5_output_0 = Gather[axis = 1](%/body/body.3/body/body.1/skff_mid_1/Reshape_1_output_0, %/conv_in/Constant_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Exp_2_output_0 = Exp(%/body/body.3/body/body.1/skff_mid_1/Gather_5_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Add_output_0 = Add(%/body/body.3/body/body.1/skff_mid_1/Exp_1_output_0, %/body/body.3/body/body.1/skff_mid_1/Exp_2_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Constant_8_output_0 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_6_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_mid_1/Add_output_0, %/body/body.3/body/body.1/skff_mid_1/Constant_8_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Concat_4_output_0 = Concat[axis = 1](%/body/body.3/body/body.1/skff_mid_1/Unsqueeze_6_output_0, %/body/body.3/body/body.1/skff_mid_1/Unsqueeze_6_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Div_output_0 = Div(%/body/body.3/body/body.1/skff_mid_1/Exp_output_0, %/body/body.3/body/body.1/skff_mid_1/Concat_4_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/Mul_output_0 = Mul(%/body/body.3/body/body.1/skff_mid_1/Reshape_output_0, %/body/body.3/body/body.1/skff_mid_1/Div_output_0)
#   %/body/body.3/body/body.1/skff_mid_1/ReduceSum_1_output_0 = ReduceSum[keepdims = 0](%/body/body.3/body/body.1/skff_mid_1/Mul_output_0, %onnx::ReduceSum_444)
#   %/body/body.3/body/body.1/up21_2/body/body.0/bot/bot.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.3/body/body.1/skff_mid_1/ReduceSum_1_output_0, %body.3.body.1.up21_2.body.0.bot.0.weight)
#   %/body/body.3/body/body.1/up21_2/body/body.0/bot/bot.1/Constant_output_0 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/up21_2/body/body.0/bot/bot.1/Resize_output_0 = Resize[coordinate_transformation_mode = 'half_pixel', cubic_coeff_a = -0.75, mode = 'linear', nearest_mode = 'floor'](%/body/body.3/body/body.1/up21_2/body/body.0/bot/bot.0/Conv_output_0, %, %/body/body.3/body/body.1/up21_2/body/body.0/bot/bot.1/Constant_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Shape_output_0 = Shape(%/body/body.3/body/body.1/dau_top_1/Add_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.3/body/body.1/skff_top_1/Gather_output_0 = Gather[axis = 0](%/body/body.3/body/body.1/skff_top_1/Shape_output_0, %/body/body.3/body/body.1/skff_top_1/Constant_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Shape_1_output_0 = Shape(%/body/body.3/body/body.1/dau_top_1/Add_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.3/body/body.1/skff_top_1/Gather_1_output_0 = Gather[axis = 0](%/body/body.3/body/body.1/skff_top_1/Shape_1_output_0, %/body/body.3/body/body.1/skff_top_1/Constant_1_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Concat_output_0 = Concat[axis = 1](%/body/body.3/body/body.1/dau_top_1/Add_output_0, %/body/body.3/body/body.1/up21_2/body/body.0/bot/bot.1/Resize_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Shape_2_output_0 = Shape(%/body/body.3/body/body.1/skff_top_1/Concat_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Constant_2_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.3/body/body.1/skff_top_1/Gather_2_output_0 = Gather[axis = 0](%/body/body.3/body/body.1/skff_top_1/Shape_2_output_0, %/body/body.3/body/body.1/skff_top_1/Constant_2_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Shape_3_output_0 = Shape(%/body/body.3/body/body.1/skff_top_1/Concat_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Constant_3_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/body/body.3/body/body.1/skff_top_1/Gather_3_output_0 = Gather[axis = 0](%/body/body.3/body/body.1/skff_top_1/Shape_3_output_0, %/body/body.3/body/body.1/skff_top_1/Constant_3_output_0)
#   %onnx::Unsqueeze_4885 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_top_1/Unsqueeze_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_top_1/Gather_output_0, %onnx::Unsqueeze_4885)
#   %/body/body.3/body/body.1/skff_top_1/Constant_4_output_0 = Constant[value = <Tensor>]()
#   %onnx::Unsqueeze_4889 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_top_1/Unsqueeze_1_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_top_1/Gather_1_output_0, %onnx::Unsqueeze_4889)
#   %onnx::Unsqueeze_4891 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_top_1/Unsqueeze_2_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_top_1/Gather_2_output_0, %onnx::Unsqueeze_4891)
#   %onnx::Unsqueeze_4893 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_top_1/Unsqueeze_3_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_top_1/Gather_3_output_0, %onnx::Unsqueeze_4893)
#   %/body/body.3/body/body.1/skff_top_1/Concat_1_output_0 = Concat[axis = 0](%/body/body.3/body/body.1/skff_top_1/Unsqueeze_output_0, %/body/body.3/body/body.1/skff_top_1/Constant_4_output_0, %/body/body.3/body/body.1/skff_top_1/Unsqueeze_1_output_0, %/body/body.3/body/body.1/skff_top_1/Unsqueeze_2_output_0, %/body/body.3/body/body.1/skff_top_1/Unsqueeze_3_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Reshape_output_0 = Reshape(%/body/body.3/body/body.1/skff_top_1/Concat_output_0, %/body/body.3/body/body.1/skff_top_1/Concat_1_output_0)
#   %/body/body.3/body/body.1/skff_top_1/ReduceSum_output_0 = ReduceSum[keepdims = 0](%/body/body.3/body/body.1/skff_top_1/Reshape_output_0, %onnx::ReduceSum_444)
#   %/body/body.3/body/body.1/skff_top/avg_pool_1/GlobalAveragePool_output_0 = GlobalAveragePool(%/body/body.3/body/body.1/skff_top_1/ReduceSum_output_0)
#   %/body/body.3/body/body.1/skff_top/conv_du/conv_du.0_1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.3/body/body.1/skff_top/avg_pool_1/GlobalAveragePool_output_0, %body.3.body.1.skff_top.conv_du.0.weight)
#   %/body/body.3/body/body.1/skff_top/conv_du/conv_du.1_1/LeakyRelu_output_0 = LeakyRelu[alpha = 0.200000002980232](%/body/body.3/body/body.1/skff_top/conv_du/conv_du.0_1/Conv_output_0)
#   %/body/body.3/body/body.1/skff_top/fcs.0_1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.3/body/body.1/skff_top/conv_du/conv_du.1_1/LeakyRelu_output_0, %body.3.body.1.skff_top.fcs.0.weight)
#   %/body/body.3/body/body.1/skff_top/fcs.1_1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.3/body/body.1/skff_top/conv_du/conv_du.1_1/LeakyRelu_output_0, %body.3.body.1.skff_top.fcs.1.weight)
#   %/body/body.3/body/body.1/skff_top_1/Concat_2_output_0 = Concat[axis = 1](%/body/body.3/body/body.1/skff_top/fcs.0_1/Conv_output_0, %/body/body.3/body/body.1/skff_top/fcs.1_1/Conv_output_0)
#   %onnx::Unsqueeze_4904 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_top_1/Unsqueeze_4_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_top_1/Gather_output_0, %onnx::Unsqueeze_4904)
#   %/body/body.3/body/body.1/skff_top_1/Constant_5_output_0 = Constant[value = <Tensor>]()
#   %onnx::Unsqueeze_4908 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_top_1/Unsqueeze_5_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_top_1/Gather_1_output_0, %onnx::Unsqueeze_4908)
#   %/body/body.3/body/body.1/skff_top_1/Constant_6_output_0 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_top_1/Constant_7_output_0 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_top_1/Concat_3_output_0 = Concat[axis = 0](%/body/body.3/body/body.1/skff_top_1/Unsqueeze_4_output_0, %/body/body.3/body/body.1/skff_top_1/Constant_5_output_0, %/body/body.3/body/body.1/skff_top_1/Unsqueeze_5_output_0, %/body/body.3/body/body.1/skff_top_1/Constant_6_output_0, %/body/body.3/body/body.1/skff_top_1/Constant_7_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Reshape_1_output_0 = Reshape(%/body/body.3/body/body.1/skff_top_1/Concat_2_output_0, %/body/body.3/body/body.1/skff_top_1/Concat_3_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Exp_output_0 = Exp(%/body/body.3/body/body.1/skff_top_1/Reshape_1_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Gather_4_output_0 = Gather[axis = 1](%/body/body.3/body/body.1/skff_top_1/Reshape_1_output_0, %/body/body.0/body/body.0/dau_top/gcnet/Constant_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Exp_1_output_0 = Exp(%/body/body.3/body/body.1/skff_top_1/Gather_4_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Gather_5_output_0 = Gather[axis = 1](%/body/body.3/body/body.1/skff_top_1/Reshape_1_output_0, %/conv_in/Constant_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Exp_2_output_0 = Exp(%/body/body.3/body/body.1/skff_top_1/Gather_5_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Add_output_0 = Add(%/body/body.3/body/body.1/skff_top_1/Exp_1_output_0, %/body/body.3/body/body.1/skff_top_1/Exp_2_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Constant_8_output_0 = Constant[value = <Tensor>]()
#   %/body/body.3/body/body.1/skff_top_1/Unsqueeze_6_output_0 = Unsqueeze(%/body/body.3/body/body.1/skff_top_1/Add_output_0, %/body/body.3/body/body.1/skff_top_1/Constant_8_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Concat_4_output_0 = Concat[axis = 1](%/body/body.3/body/body.1/skff_top_1/Unsqueeze_6_output_0, %/body/body.3/body/body.1/skff_top_1/Unsqueeze_6_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Div_output_0 = Div(%/body/body.3/body/body.1/skff_top_1/Exp_output_0, %/body/body.3/body/body.1/skff_top_1/Concat_4_output_0)
#   %/body/body.3/body/body.1/skff_top_1/Mul_output_0 = Mul(%/body/body.3/body/body.1/skff_top_1/Reshape_output_0, %/body/body.3/body/body.1/skff_top_1/Div_output_0)
#   %/body/body.3/body/body.1/skff_top_1/ReduceSum_1_output_0 = ReduceSum[keepdims = 0](%/body/body.3/body/body.1/skff_top_1/Mul_output_0, %onnx::ReduceSum_444)
#   %/body/body.3/body/body.1/conv_out/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/body/body.3/body/body.1/skff_top_1/ReduceSum_1_output_0, %body.3.body.1.conv_out.weight)
#   %/body/body.3/body/body.1/Add_output_0 = Add(%/body/body.3/body/body.1/conv_out/Conv_output_0, %/body/body.3/body/body.0/Add_output_0)
#   %/body/body.3/body/body.2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/body/body.3/body/body.1/Add_output_0, %body.3.body.2.weight)
#   %/body/body.3/Add_output_0 = Add(%/body/body.3/body/body.2/Conv_output_0, %/body/body.2/Add_output_0)
#   %/conv_out/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/body/body.3/Add_output_0, %conv_out.weight)
#   %output = Add(%/conv_out/Conv_output_0, %input)
#   return %output
# }

# %% [markdown]
# #### ONNX 모델 양자화

# %%
onnx_model_quantized_path = "./onnx_models/mirnet_sh.onnx"
quantize_dynamic(
    model_input=onnx_model_path,
    model_output=onnx_model_quantized_path,
    #optimize_model=True,
    per_channel=False,
    reduce_range=False,
    weight_type=QuantType.QUInt8,
)
#onnx_model_path = onnx_model_quantized_path
# Out:
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.0/dau_top/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.0/dau_mid/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.0/dau_bot/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.0/dau_top/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.0/dau_mid/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.0/dau_bot/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.1/dau_top/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.1/dau_mid/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.1/dau_bot/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.1/dau_top/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.1/dau_mid/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.0/body/body.1/dau_bot/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.0/dau_top/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.0/dau_mid/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.0/dau_bot/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.0/dau_top/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.0/dau_mid/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.0/dau_bot/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.1/dau_top/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.1/dau_mid/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.1/dau_bot/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.1/dau_top/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.1/dau_mid/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.1/body/body.1/dau_bot/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.0/dau_top/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.0/dau_mid/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.0/dau_bot/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.0/dau_top/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.0/dau_mid/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.0/dau_bot/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.1/dau_top/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.1/dau_mid/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.1/dau_bot/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.1/dau_top/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.1/dau_mid/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.2/body/body.1/dau_bot/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.0/dau_top/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.0/dau_mid/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.0/dau_bot/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.0/dau_top/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.0/dau_mid/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.0/dau_bot/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.1/dau_top/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.1/dau_mid/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.1/dau_bot/gcnet/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.1/dau_top/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.1/dau_mid/gcnet_1/MatMul]
# Ignore MatMul due to non constant B: /[/body/body.3/body/body.1/dau_bot/gcnet_1/MatMul]

# %% [markdown]
# ## Test - Using an ONNX model

# %%
# test 이미지
import Enhancement.utils as utils

factor = 4

img = np.float32(utils.load_img('disney01.png'))/255
img = cv2.resize(img, (356, 356))
plt.imshow(img)
img = torch.from_numpy(img).permute(2,0,1)
input_ = img.unsqueeze(0)
# Padding in case images are not multiples of 4
h,w = input_.shape[2], input_.shape[3]
H,W = ((h+factor)//factor)*factor, ((w+factor)//factor)*factor
padh = H-h if h%factor!=0 else 0
padw = W-w if w%factor!=0 else 0
input_ = F.pad(input_, (0,padw,0,padh), 'reflect')

# loading
ort_session = onnxruntime.InferenceSession(onnx_model_quantized_path, providers=['AzureExecutionProvider'])

image_embedding = input_.detach().cpu().numpy()

# 테스트 실행
ort_inputs  = {ort_session.get_inputs()[0].name : image_embedding}
ort_outputs = ort_session.run(None, ort_inputs)

# %%
from PIL import Image
from skimage import img_as_ubyte
ort_output = torch.tensor(ort_outputs[0])
final_output = torch.clamp(ort_output,0,1).cpu().detach().permute(0, 2, 3, 1).squeeze(0).numpy()

utils.save_img('./disney01_result.png', img_as_ubyte(final_output))
plt.imshow(final_output)
